# %%
import numpy as np
X = np.array([500,600,700,800,900]) #plot sqaure fit 
Y = np.array([500000,600000,700000,800000,900000])# price of the plot

# neumenator

XY = X*Y
print("the multiplication of x and y",XY)
meanofXY = np.mean(XY)
print("the mean of xy is",meanofXY)
meanofX = np.mean(X)
print("the mean of x is",meanofX)
meanofY = np.mean(Y)
print("the mean of y is",meanofY)
meanofXmultiplybymeanofY = meanofX * meanofY
print("the multiplication of mean of x and mean of y is",meanofXmultiplybymeanofY)
thevalueofnominator = meanofXY - meanofXmultiplybymeanofY
print("the value of nominator is",thevalueofnominator)
# denomenatore
squareofX = np.square(X)
print("the square of x is",squareofX)
meanofsquareofX = np.mean(squareofX)
print("the mean of square of x is",meanofsquareofX)
squareofmeanofX = np.square(meanofX)
print("the square of mean of the x is",squareofmeanofX)
thevalueofdenominator = meanofsquareofX - squareofmeanofX
print("the value of denominator is",thevalueofdenominator)
#slope
m = thevalueofnominator/thevalueofdenominator
print("the value of m is",m)
themultiplicationofmandmeanofX = m * meanofX
print("the multiplication of m and mean of x is",themultiplicationofmandmeanofX)
b = meanofY - themultiplicationofmandmeanofX 
print("the value of b is",b)
# pridictive
y = m*2000 + b
print("the pridicted value is ", y)
# Out:
# the multiplication of x and y [250000000 360000000 490000000 640000000 810000000]
# the mean of xy is 510000000.0
# the mean of x is 700.0
# the mean of y is 700000.0
# the multiplication of mean of x and mean of y is 490000000.0
# the value of nominator is 20000000.0
# the square of x is [250000 360000 490000 640000 810000]
# the mean of square of x is 510000.0
# the square of mean of the x is 490000.0
# the value of denominator is 20000.0
# the value of m is 1000.0
# the multiplication of m and mean of x is 700000.0
# the value of b is 0.0
# the pridicted value is  2000000.0
