# %%
import numpy as np
x = np.array([8,9,10,11,12])
y = np.array([15000,20000,30000,40000,50000])
#neumenator
xy=x*y
print("Multiplication of x and y",xy)
meanofxandy= np.mean(xy)
print("Mean of x and y:",meanofxandy)
meanofx=np.mean(x)
print("mean of x",meanofx)
meanofy=np.mean(y)
print("Mean of y",meanofy)
mulbothmeans=meanofx * meanofy
print("Multiplication of both means", mulbothmeans)
neumenatorvalue = meanofxandy - mulbothmeans
print("Neumenatore value is:",neumenatorvalue)
#Denomenator
xsquare= x**2
print("Square of x",xsquare)
meanofxsquare=np.mean(xsquare)
print("Mean of x Square",meanofxsquare)
squareofmeanx= meanofx**2
print("Suare of meanx",squareofmeanx)
denomenatorvalue=meanofxsquare - squareofmeanx
print("denomenator value is:",denomenatorvalue)
#slope
m= neumenatorvalue / denomenatorvalue
print("Slope is:", m)
# intercept
b= m*meanofx - meanofy
print("The value of intercept is: ",B)
# priict salary 
salary = m*7+b
print("Pridict of salary in 7 year is: ",salary)
salary2= m*10+b
print("Pridict of salary in 10 year is: ",salary2)
salary3= m*0+b
print("Pridict of salary in 0 year is",salary3)
# Out:
# Multiplication of x and y [120000 180000 300000 440000 600000]
# Mean of x and y: 328000.0
# mean of x 10.0
# Mean of y 31000.0
# Multiplication of both means 310000.0
# Neumenatore value is: 18000.0
# Square of x [ 64  81 100 121 144]
# Mean of x Square 102.0
# Suare of meanx 100.0
# denomenator value is: 2.0
# Slope is: 9000.0
# The value of intercept is:  59000.0
# Pridict of salary in 7 year is:  122000.0
# Pridict of salary in 10 year is:  149000.0
# Pridict of salary in 0 year is 59000.0
